# %% [markdown]
# ## In Synthetic data

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_classification

# %%
X, y = make_classification(n_samples = 500, n_features = 2, n_redundant = 0, n_informative = 2, n_clusters_per_class = 1, n_classes = 2, random_state = 8)

print(X.shape, y.shape)

_, ax = plt.subplots(figsize=(5, 4))
ax.scatter( X[:,0], X[:,1], c = y, edgecolors = 'k', cmap = 'Paired')
# Out:
# (500, 2) (500,)

# %%
# Crear una instancia
logistic_regression = LogisticRegression()

# Entrenar el modelo
logistic_regression.fit ( X, y) #Para X siempre deben estar con la forma: (Muestras, Características) y no (Características, Muestras)
# Out:
# LogisticRegression()

# %%
print(logistic_regression.coef_ , logistic_regression.intercept_)
# Out:
# [[-2.05708959  1.85247996]] [-1.61624314]

# %% [markdown]
# ### Decision boundaries

# %%
# Min-Max values for the grid of decision boundaries
offset = 0.5
h_min, h_max = min(X[:,0]) - offset, max(X[:,0]) + offset
v_min, v_max = min(X[:,1]) - offset, max(X[:,1]) + offset

# Create grid
h_grid, v_grid = np.meshgrid( np.linspace(h_min, h_max, 100), np.linspace(v_min, v_max, 100))
print(h_grid.shape, v_grid.shape)
print(h_grid.ravel().shape, v_grid.ravel().shape)
print(np.concatenate([h_grid.ravel().reshape(-1,1), v_grid.ravel().reshape(-1,1)], axis=1).shape) #Forma no simplificada de concatenar
print(np.c_[h_grid.ravel(), v_grid.ravel()].shape) #Forma simplificada de concatenar

# Estimate predictions over the grid
pred_grid = logistic_regression.predict(np.c_[h_grid.ravel(), v_grid.ravel()])
print (pred_grid.shape)
pred_grid = pred_grid.reshape(h_grid.shape)
print(pred_grid.shape)
# Out:
# (100, 100) (100, 100)
# (10000,) (10000,)
# (10000, 2)
# (10000, 2)
# (10000,)
# (100, 100)

# %%
h_grid.ravel()
# h_grid.ravel().shape
# Out:
# array([-4.35890028, -4.27793977, -4.19697927, ...,  3.49426876,
#         3.57522926,  3.65618977])

# %%
# Draw grid
_, ax = plt.subplots (figsize=(6,5))
ax.pcolormesh( h_grid, v_grid, pred_grid, cmap = "Paired")

# Scatter real values
ax.scatter ( X[:,0], X[:,1], c = y, edgecolors = 'k', cmap = "Paired")

ax.set_xticks(())
ax.set_yticks(())
# Out:
# []

# %% [markdown]
# ### Ejercicio In Real Data

# %%
from sklearn.datasets import load_iris

# %%
X, y = load_iris(return_X_y=True)
print(X.shape,y.shape)
# Out:
# (150, 4) (150,)
